# %% [markdown]
# 9# Data Analysis with Python

# %%
import pandas as pd

# %%
data=pd.read_csv("Downloads/Compressed/gdp_data.csv",skiprows=4)

# %%
data.head()
# Out:
#   Country Name Country Code                Indicator Name  Indicator Code  \
# 0        Aruba          ABW  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1  Afghanistan          AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2       Angola          AGO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3      Albania          ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4      Andorra          AND  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#         1960       1961       1962       1963       1964        1965  ...  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 1  59.773194  59.860874  58.458015  78.706388  82.095231  101.108305  ...
# 2        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 3        NaN        NaN        NaN        NaN        NaN         NaN  ...
# 4        NaN        NaN        NaN        NaN        NaN         NaN  ...
#
#            2011          2012          2013          2014          2015  \
# ...

# %%
data.shape
# Out:
# (264, 65)

# %%
data
# Out:
#      Country Name Country Code                Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1     Afghanistan          AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2          Angola          AGO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3         Albania          ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4         Andorra          AND  GDP per capita (current US$)  NY.GDP.PCAP.CD
# ..            ...          ...                           ...             ...
# 259        Kosovo          XKX  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 260   Yemen, Rep.          YEM  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 261  South Africa          ZAF  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 262        Zambia          ZMB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 263      Zimbabwe          ZWE  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
# ...

# %%
data
# Out:
#      Country Name Country Code                Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1     Afghanistan          AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2          Angola          AGO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3         Albania          ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4         Andorra          AND  GDP per capita (current US$)  NY.GDP.PCAP.CD
# ..            ...          ...                           ...             ...
# 259        Kosovo          XKX  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 260   Yemen, Rep.          YEM  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 261  South Africa          ZAF  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 262        Zambia          ZMB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 263      Zimbabwe          ZWE  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
# ...

# %%
# setting index
data.set_index("Country Name",inplace=True)

# %%
data.head()
# Out:
#              Country Code                Indicator Name  Indicator Code  \
# Country Name
# Aruba                 ABW  GDP per capita (current US$)  NY.GDP.PCAP.CD
# Afghanistan           AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# Angola                AGO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# Albania               ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# Andorra               AND  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#                    1960       1961       1962       1963       1964  \
# Country Name
# Aruba               NaN        NaN        NaN        NaN        NaN
# Afghanistan   59.773194  59.860874  58.458015  78.706388  82.095231
# Angola              NaN        NaN        NaN        NaN        NaN
# Albania             NaN        NaN        NaN        NaN        NaN
# Andorra             NaN        NaN        NaN        NaN        NaN
#
#                     1965        1966  ...          2011          2012  \
# ...

# %%
data.drop(labels=["Indicator Name","Indicator Code","Unnamed: 64"],axis="columns",inplace=True)

# %%
data.head()
# Out:
#              Country Code       1960       1961       1962       1963  \
# Country Name
# Aruba                 ABW        NaN        NaN        NaN        NaN
# Afghanistan           AFG  59.773194  59.860874  58.458015  78.706388
# Angola                AGO        NaN        NaN        NaN        NaN
# Albania               ALB        NaN        NaN        NaN        NaN
# Andorra               AND        NaN        NaN        NaN        NaN
#
#                    1964        1965        1966        1967        1968  ...  \
# Country Name                                                             ...
# Aruba               NaN         NaN         NaN         NaN         NaN  ...
# Afghanistan   82.095231  101.108305  137.594352  160.898589  129.108323  ...
# Angola              NaN         NaN         NaN         NaN         NaN  ...
# Albania             NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
Pak=data.loc["Pakistan"]
italy=data.loc["Italy"]

# %%
Pak
# Out:
# Country Code        PAK
# 1960            83.3379
# 1961             89.409
# 1962            91.3192
# 1963            95.7034
#                  ...
# 2015            1356.67
# 2016            1368.45
# 2017            1464.99
# 2018            1482.31
# 2019             1284.7
# Name: Pakistan, Length: 61, dtype: object

# %%
type(italy)
# Out:
# pandas.core.series.Series

# %%
type(Pak)
# Out:
# pandas.core.series.Series

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
italy["2019"]
# Out:
# 33189.5657988542

# %%
italy.head()
# Out:
# Country Code        ITA
# 1960            804.493
# 1961            887.337
# 1962             990.26
# 1963            1126.02
# Name: Italy, dtype: object

# %%
Pak["2019"]
# Out:
# 1284.70204090039

# %%
Pak.head()
# Out:
# Country Code        PAK
# 1960            83.3379
# 1961             89.409
# 1962            91.3192
# 1963            95.7034
# Name: Pakistan, dtype: object

# %%
Pak.tail()
# Out:
# 2015    1356.67
# 2016    1368.45
# 2017    1464.99
# 2018    1482.31
# 2019     1284.7
# Name: Pakistan, dtype: object

# %%
#converting datagrame object to numeric
Pak1=pd.to_numeric(Pak, errors='coerce')

# %%
Pak_pct_change=Pak1.pct_change()

# %%
Pak_pct_change.head()
# Out:
# Country Code         NaN
# 1960                 NaN
# 1961            0.072849
# 1962            0.021364
# 1963            0.048009
# Name: Pakistan, dtype: float64

# %%
Pak_pct_change=Pak_pct_change*100

# %%
Pak_pct_change
# Out:
# Country Code          NaN
# 1960                  NaN
# 1961             7.284898
# 1962             2.136440
# 1963             4.800920
#                   ...
# 2015             8.432439
# 2016             0.868788
# 2017             7.054600
# 2018             1.181737
# 2019           -13.330828
# Name: Pakistan, Length: 61, dtype: float64

# %%
italy2=pd.to_numeric(italy,errors="coerce")

# %%
italy_pct_change=italy2.pct_change()

# %%
italy_pct_change
# Out:
# Country Code         NaN
# 1960                 NaN
# 1961            0.102977
# 1962            0.115991
# 1963            0.137094
#                   ...
# 2015           -0.148886
# 2016            0.023469
# 2017            0.047415
# 2018            0.065214
# 2019           -0.038543
# Name: Italy, Length: 61, dtype: float64

# %%
italy_pct_change=italy_pct_change*100

# %%
italy_pct_change
# Out:
# Country Code          NaN
# 1960                  NaN
# 1961            10.297686
# 1962            11.599137
# 1963            13.709446
#                   ...
# 2015           -14.888584
# 2016             2.346949
# 2017             4.741498
# 2018             6.521378
# 2019            -3.854334
# Name: Italy, Length: 61, dtype: float64

# %%
italy_pct_change.idxmax()
# Out:
# '1986'

# %%
italy_pct_change.max()
# Out:
# 41.60254037779829

# %%
Pak_pct_change.idxmax(
)
# Out:
# '1974'

# %%
Pak_pct_change.max()
# Out:
# 3553.0470523257864
